# %%
import pandas as pd

podaci = pd.read_json("../data-etfbl/podaci-rs.txt" )
podaci
# Out:
#           datum entitet  novi  umrli  oporavljeni  testirani  kriticni
# 0    2020-03-05      rs     2      0            0          0         0
# 1    2020-03-06      rs     1      0            0          0         0
# 2    2020-03-07      rs     0      0            0          0         0
# 3    2020-03-08      rs     0      0            0          0         0
# 4    2020-03-09      rs     1      0            0          0         0
# ..          ...     ...   ...    ...          ...        ...       ...
# 292  2020-12-22      rs   180     22            0          0         0
# 293  2020-12-23      rs   226     34            0          0         0
# 294  2020-12-24      rs   233     20            0          0         0
# 295  2020-12-25      rs   240     16            0          0         0
# 296  2020-12-26      rs   241     14            0          0         0
#
# [297 rows x 7 columns]

# %%
podaci_po_gradovima = pd.read_json("podaci_po_gradovima2.txt" )
podaci_po_gradovima
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-9f122dd2116f> in <module>
# ----> 1 podaci_po_gradovima = pd.read_json("podaci_po_gradovima2.txt" )
#       2 podaci_po_gradovima
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     606         return json_reader
#     607
# --> 608     result = json_reader.read()
#     609     if should_close:
#     610         filepath_or_buffer.close()
#
# ...

# %%
with open("podaci_po_gradovima2.txt", "r") as f:
    s = f.readlines()
    print(s)
# Out:
# ["[{'datum': '2020-03-05'}, \n", "{'datum': '2020-03-06'}, \n", "{'datum': '2020-03-07'}, \n", "{'datum': '2020-03-08'}, \n", "{'datum': '2020-03-09'}, \n", "{'datum': '2020-03-10'}, \n", "{'datum': '2020-03-11'}, \n", "{'datum': '2020-03-12'}\n", ' ]']
